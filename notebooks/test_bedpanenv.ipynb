# %%
# %%capture _

from assistive_gym.learn import render_policy
from IPython.display import Image

from riddbot.gym import make_env

# %%
# %%capture
env_name, env = make_env()

# %%
# %%time
filename = render_policy(env, env_name, algo="ppo", policy_path="", colab=True, seed=0)
# Out:
# 2021-02-21 18:31:22,459	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-02-21 18:31:37,649	INFO trainable.py:103 -- Trainable.setup took 13.405 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2021-02-21 18:31:37,650	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# CPU times: user 14.3 s, sys: 454 ms, total: 14.8 s
# Wall time: 26 s

# %%
Image(filename)
